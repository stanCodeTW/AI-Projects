# %% [markdown]
# ## 環境設置

# %%
# Mount to Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install nnunetv2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.3/206.3 kB 12.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 79.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 101.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 104.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 6.5 MB/s eta 0:00:00
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Building wheel for acvl-utils (setup.py) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Building wheel for dynamic-network-architectures (setup.py) ... done

# %%
import os

os.environ['nnUNet_raw'] = '/content/nnUNet_raw'
os.environ['nnUNet_preprocessed'] = '/content/nnUNet_preprocessed'
os.environ['nnUNet_results'] = '/content/drive/MyDrive/poster/NNUNET/nnUNet_results'

# %% [markdown]
# ## 用程式碼上傳raw

# %%
import os
import shutil
import time
import gc
from tqdm import tqdm

def copy_single_file(src_file, dest_file):
    """Copy a single file with error handling"""
    try:
        # Create parent directories if they don't exist
        os.makedirs(os.path.dirname(dest_file), exist_ok=True)

        # Copy the file
        shutil.copy2(src_file, dest_file)
        return True
    except Exception as e:
        print(f"Error copying {src_file} to {dest_file}: {str(e)}")
        return False

def get_all_files(source_dir):
    """Get a list of all files in the directory and its subdirectories"""
    all_files = []
    for root, _, files in os.walk(source_dir):
        for file in files:
            src_file = os.path.join(root, file)
            all_files.append(src_file)
    return all_files

def robust_copy_directory(source_dir, dest_dir, start_idx=0, batch_size=5, sleep_time=2):
    """
    Copy files from source_dir to dest_dir with memory management

    Args:
        source_dir: Source directory
        dest_dir: Destination directory
        start_idx: Index to start copying from (useful for resuming)
        batch_size: Number of files to copy before pausing
        sleep_time: Time to sleep between batches in seconds
    """
    # Create destination directory if it doesn't exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # Get list of all files
    all_files = get_all_files(source_dir)
    total_files = len(all_files)

    if start_idx >= total_files:
        print(f"Start index {start_idx} is greater than total files {total_files}")
        return

    print(f"Found {total_files} files to copy, starting from index {start_idx}")

    # Process files in small batches
    for i in range(start_idx, total_files, batch_size):
        batch_end = min(i + batch_size, total_files)
        print(f"\nProcessing batch {i//batch_size + 1}: files {i+1}-{batch_end} of {total_files}")

        # Process each file in the current batch
        for j in range(i, batch_end):
            src_file = all_files[j]
            # Calculate relative path to maintain directory structure
            rel_path = os.path.relpath(src_file, source_dir)
            dest_file = os.path.join(dest_dir, rel_path)

            print(f"Copying file {j+1}/{total_files}: {rel_path}")
            success = copy_single_file(src_file, dest_file)

            # Force garbage collection after each file
            gc.collect()

        # After each batch, print progress and pause
        print(f"Completed {batch_end}/{total_files} files ({(batch_end/total_files)*100:.1f}%)")

        if batch_end < total_files:
            print(f"Pausing for {sleep_time} seconds before next batch...")
            time.sleep(sleep_time)

            # More aggressive garbage collection every 50 files
            if (batch_end % 50) < batch_size:
                print("Performing extensive garbage collection...")
                for _ in range(3):
                    gc.collect()
                time.sleep(5)

            # Print resume information
            print(f"""
If this process freezes, you can resume by running:
robust_copy_directory("{source_dir}", "{dest_dir}", start_idx={batch_end}, batch_size={batch_size})
""")

    print(f"\nCopy complete! Copied {total_files} files from {source_dir} to {dest_dir}")

def verify_copy(source_dir, dest_dir):
    """Verify that all files were copied correctly"""
    source_files = get_all_files(source_dir)
    dest_files = get_all_files(dest_dir)

    # Convert to relative paths for comparison
    source_rel_paths = set(os.path.relpath(f, source_dir) for f in source_files)
    dest_rel_paths = set(os.path.relpath(f, dest_dir) for f in dest_files)

    missing_files = source_rel_paths - dest_rel_paths

    print(f"Source files: {len(source_rel_paths)}")
    print(f"Destination files: {len(dest_rel_paths)}")

    if missing_files:
        print(f"WARNING: {len(missing_files)} files were not copied!")
        if len(missing_files) < 10:
            print("Missing files:")
            for f in missing_files:
                print(f"  - {f}")
        else:
            print("First 10 missing files:")
            for f in list(missing_files)[:10]:
                print(f"  - {f}")
    else:
        print("All files were copied successfully!")

# %%
source_directory = '/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial'
destination_directory = '/content/nnUNet_raw/Dataset003_aocr2024_partial'

robust_copy_directory(source_directory, destination_directory)

# After copying completes, verify that everything was copied correctly
verify_copy(source_directory, destination_directory)
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing batch 20: files 96-100 of 2001
# Copying file 96/2001: imagesTr/PARTIAL_0095_0000.nii.gz
# Copying file 97/2001: imagesTr/PARTIAL_0096_0000.nii.gz
# Copying file 98/2001: imagesTr/PARTIAL_0097_0000.nii.gz
# Copying file 99/2001: imagesTr/PARTIAL_0098_0000.nii.gz
# Copying file 100/2001: imagesTr/PARTIAL_0099_0000.nii.gz
# Completed 100/2001 files (5.0%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=100, batch_size=5)
#
#
# Processing batch 21: files 101-105 of 2001
# Copying file 101/2001: imagesTr/PARTIAL_0100_0000.nii.gz
# Copying file 102/2001: imagesTr/PARTIAL_0101_0000.nii.gz
# Copying file 103/2001: imagesTr/PARTIAL_0102_0000.nii.gz
# Copying file 104/2001: imagesTr/PARTIAL_0103_0000.nii.gz
# Copying file 105/2001: imagesTr/PARTIAL_0104_0000.nii.gz
# Completed 105/2001 files (5.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=105, batch_size=5)
#
#
# Processing batch 22: files 106-110 of 2001
# Copying file 106/2001: imagesTr/PARTIAL_0105_0000.nii.gz
# Copying file 107/2001: imagesTr/PARTIAL_0106_0000.nii.gz
# Copying file 108/2001: imagesTr/PARTIAL_0107_0000.nii.gz
# Copying file 109/2001: imagesTr/PARTIAL_0108_0000.nii.gz
# Copying file 110/2001: imagesTr/PARTIAL_0109_0000.nii.gz
# Completed 110/2001 files (5.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=110, batch_size=5)
#
#
# Processing batch 23: files 111-115 of 2001
# Copying file 111/2001: imagesTr/PARTIAL_0110_0000.nii.gz
# Copying file 112/2001: imagesTr/PARTIAL_0111_0000.nii.gz
# Copying file 113/2001: imagesTr/PARTIAL_0112_0000.nii.gz
# Copying file 114/2001: imagesTr/PARTIAL_0113_0000.nii.gz
# Copying file 115/2001: imagesTr/PARTIAL_0114_0000.nii.gz
# Completed 115/2001 files (5.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=115, batch_size=5)
#
#
# Processing batch 24: files 116-120 of 2001
# Copying file 116/2001: imagesTr/PARTIAL_0115_0000.nii.gz
# Copying file 117/2001: imagesTr/PARTIAL_0116_0000.nii.gz
# Copying file 118/2001: imagesTr/PARTIAL_0117_0000.nii.gz
# Copying file 119/2001: imagesTr/PARTIAL_0118_0000.nii.gz
# Copying file 120/2001: imagesTr/PARTIAL_0119_0000.nii.gz
# Completed 120/2001 files (6.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=120, batch_size=5)
#
#
# Processing batch 25: files 121-125 of 2001
# Copying file 121/2001: imagesTr/PARTIAL_0120_0000.nii.gz
# Copying file 122/2001: imagesTr/PARTIAL_0121_0000.nii.gz
# Copying file 123/2001: imagesTr/PARTIAL_0122_0000.nii.gz
# Copying file 124/2001: imagesTr/PARTIAL_0123_0000.nii.gz
# Copying file 125/2001: imagesTr/PARTIAL_0124_0000.nii.gz
# Completed 125/2001 files (6.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=125, batch_size=5)
#
#
# Processing batch 26: files 126-130 of 2001
# Copying file 126/2001: imagesTr/PARTIAL_0125_0000.nii.gz
# Copying file 127/2001: imagesTr/PARTIAL_0126_0000.nii.gz
# Copying file 128/2001: imagesTr/PARTIAL_0127_0000.nii.gz
# Copying file 129/2001: imagesTr/PARTIAL_0128_0000.nii.gz
# Copying file 130/2001: imagesTr/PARTIAL_0129_0000.nii.gz
# Completed 130/2001 files (6.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=130, batch_size=5)
#
#
# Processing batch 27: files 131-135 of 2001
# Copying file 131/2001: imagesTr/PARTIAL_0130_0000.nii.gz
# Copying file 132/2001: imagesTr/PARTIAL_0131_0000.nii.gz
# Copying file 133/2001: imagesTr/PARTIAL_0132_0000.nii.gz
# Copying file 134/2001: imagesTr/PARTIAL_0133_0000.nii.gz
# Copying file 135/2001: imagesTr/PARTIAL_0134_0000.nii.gz
# Completed 135/2001 files (6.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=135, batch_size=5)
#
#
# Processing batch 28: files 136-140 of 2001
# Copying file 136/2001: imagesTr/PARTIAL_0135_0000.nii.gz
# Copying file 137/2001: imagesTr/PARTIAL_0136_0000.nii.gz
# Copying file 138/2001: imagesTr/PARTIAL_0137_0000.nii.gz
# Copying file 139/2001: imagesTr/PARTIAL_0138_0000.nii.gz
# Copying file 140/2001: imagesTr/PARTIAL_0139_0000.nii.gz
# Completed 140/2001 files (7.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=140, batch_size=5)
#
#
# Processing batch 29: files 141-145 of 2001
# Copying file 141/2001: imagesTr/PARTIAL_0140_0000.nii.gz
# Copying file 142/2001: imagesTr/PARTIAL_0141_0000.nii.gz
# Copying file 143/2001: imagesTr/PARTIAL_0142_0000.nii.gz
# Copying file 144/2001: imagesTr/PARTIAL_0143_0000.nii.gz
# Copying file 145/2001: imagesTr/PARTIAL_0144_0000.nii.gz
# Completed 145/2001 files (7.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=145, batch_size=5)
#
#
# Processing batch 30: files 146-150 of 2001
# Copying file 146/2001: imagesTr/PARTIAL_0145_0000.nii.gz
# Copying file 147/2001: imagesTr/PARTIAL_0146_0000.nii.gz
# Copying file 148/2001: imagesTr/PARTIAL_0147_0000.nii.gz
# Copying file 149/2001: imagesTr/PARTIAL_0148_0000.nii.gz
# Copying file 150/2001: imagesTr/PARTIAL_0149_0000.nii.gz
# Completed 150/2001 files (7.5%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=150, batch_size=5)
#
#
# Processing batch 31: files 151-155 of 2001
# Copying file 151/2001: imagesTr/PARTIAL_0150_0000.nii.gz
# Copying file 152/2001: imagesTr/PARTIAL_0151_0000.nii.gz
# Copying file 153/2001: imagesTr/PARTIAL_0152_0000.nii.gz
# Copying file 154/2001: imagesTr/PARTIAL_0153_0000.nii.gz
# Copying file 155/2001: imagesTr/PARTIAL_0154_0000.nii.gz
# Completed 155/2001 files (7.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=155, batch_size=5)
#
#
# Processing batch 32: files 156-160 of 2001
# Copying file 156/2001: imagesTr/PARTIAL_0155_0000.nii.gz
# Copying file 157/2001: imagesTr/PARTIAL_0156_0000.nii.gz
# Copying file 158/2001: imagesTr/PARTIAL_0157_0000.nii.gz
# Copying file 159/2001: imagesTr/PARTIAL_0158_0000.nii.gz
# Copying file 160/2001: imagesTr/PARTIAL_0159_0000.nii.gz
# Completed 160/2001 files (8.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=160, batch_size=5)
#
#
# Processing batch 33: files 161-165 of 2001
# Copying file 161/2001: imagesTr/PARTIAL_0160_0000.nii.gz
# Copying file 162/2001: imagesTr/PARTIAL_0161_0000.nii.gz
# Copying file 163/2001: imagesTr/PARTIAL_0162_0000.nii.gz
# Copying file 164/2001: imagesTr/PARTIAL_0163_0000.nii.gz
# Copying file 165/2001: imagesTr/PARTIAL_0164_0000.nii.gz
# Completed 165/2001 files (8.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=165, batch_size=5)
#
#
# Processing batch 34: files 166-170 of 2001
# Copying file 166/2001: imagesTr/PARTIAL_0165_0000.nii.gz
# Copying file 167/2001: imagesTr/PARTIAL_0166_0000.nii.gz
# Copying file 168/2001: imagesTr/PARTIAL_0167_0000.nii.gz
# Copying file 169/2001: imagesTr/PARTIAL_0168_0000.nii.gz
# Copying file 170/2001: imagesTr/PARTIAL_0169_0000.nii.gz
# Completed 170/2001 files (8.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=170, batch_size=5)
#
#
# Processing batch 35: files 171-175 of 2001
# Copying file 171/2001: imagesTr/PARTIAL_0170_0000.nii.gz
# Copying file 172/2001: imagesTr/PARTIAL_0171_0000.nii.gz
# Copying file 173/2001: imagesTr/PARTIAL_0172_0000.nii.gz
# Copying file 174/2001: imagesTr/PARTIAL_0173_0000.nii.gz
# Copying file 175/2001: imagesTr/PARTIAL_0174_0000.nii.gz
# Completed 175/2001 files (8.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=175, batch_size=5)
#
#
# Processing batch 36: files 176-180 of 2001
# Copying file 176/2001: imagesTr/PARTIAL_0175_0000.nii.gz
# Copying file 177/2001: imagesTr/PARTIAL_0176_0000.nii.gz
# Copying file 178/2001: imagesTr/PARTIAL_0177_0000.nii.gz
# Copying file 179/2001: imagesTr/PARTIAL_0178_0000.nii.gz
# Copying file 180/2001: imagesTr/PARTIAL_0179_0000.nii.gz
# Completed 180/2001 files (9.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=180, batch_size=5)
#
#
# Processing batch 37: files 181-185 of 2001
# Copying file 181/2001: imagesTr/PARTIAL_0180_0000.nii.gz
# Copying file 182/2001: imagesTr/PARTIAL_0181_0000.nii.gz
# Copying file 183/2001: imagesTr/PARTIAL_0182_0000.nii.gz
# Copying file 184/2001: imagesTr/PARTIAL_0183_0000.nii.gz
# Copying file 185/2001: imagesTr/PARTIAL_0184_0000.nii.gz
# Completed 185/2001 files (9.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=185, batch_size=5)
#
#
# Processing batch 38: files 186-190 of 2001
# Copying file 186/2001: imagesTr/PARTIAL_0185_0000.nii.gz
# Copying file 187/2001: imagesTr/PARTIAL_0186_0000.nii.gz
# Copying file 188/2001: imagesTr/PARTIAL_0187_0000.nii.gz
# Copying file 189/2001: imagesTr/PARTIAL_0188_0000.nii.gz
# Copying file 190/2001: imagesTr/PARTIAL_0189_0000.nii.gz
# Completed 190/2001 files (9.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=190, batch_size=5)
#
#
# Processing batch 39: files 191-195 of 2001
# Copying file 191/2001: imagesTr/PARTIAL_0190_0000.nii.gz
# Copying file 192/2001: imagesTr/PARTIAL_0191_0000.nii.gz
# Copying file 193/2001: imagesTr/PARTIAL_0192_0000.nii.gz
# Copying file 194/2001: imagesTr/PARTIAL_0193_0000.nii.gz
# Copying file 195/2001: imagesTr/PARTIAL_0194_0000.nii.gz
# Completed 195/2001 files (9.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=195, batch_size=5)
#
#
# Processing batch 40: files 196-200 of 2001
# Copying file 196/2001: imagesTr/PARTIAL_0195_0000.nii.gz
# Copying file 197/2001: imagesTr/PARTIAL_0196_0000.nii.gz
# Copying file 198/2001: imagesTr/PARTIAL_0197_0000.nii.gz
# Copying file 199/2001: imagesTr/PARTIAL_0198_0000.nii.gz
# Copying file 200/2001: imagesTr/PARTIAL_0199_0000.nii.gz
# Completed 200/2001 files (10.0%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=200, batch_size=5)
#
#
# Processing batch 41: files 201-205 of 2001
# Copying file 201/2001: imagesTr/PARTIAL_0200_0000.nii.gz
# Copying file 202/2001: imagesTr/PARTIAL_0201_0000.nii.gz
# Copying file 203/2001: imagesTr/PARTIAL_0202_0000.nii.gz
# Copying file 204/2001: imagesTr/PARTIAL_0203_0000.nii.gz
# Copying file 205/2001: imagesTr/PARTIAL_0204_0000.nii.gz
# Completed 205/2001 files (10.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=205, batch_size=5)
#
#
# Processing batch 42: files 206-210 of 2001
# Copying file 206/2001: imagesTr/PARTIAL_0205_0000.nii.gz
# Copying file 207/2001: imagesTr/PARTIAL_0206_0000.nii.gz
# Copying file 208/2001: imagesTr/PARTIAL_0207_0000.nii.gz
# Copying file 209/2001: imagesTr/PARTIAL_0208_0000.nii.gz
# Copying file 210/2001: imagesTr/PARTIAL_0209_0000.nii.gz
# Completed 210/2001 files (10.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=210, batch_size=5)
#
#
# Processing batch 43: files 211-215 of 2001
# Copying file 211/2001: imagesTr/PARTIAL_0210_0000.nii.gz
# Copying file 212/2001: imagesTr/PARTIAL_0211_0000.nii.gz
# Copying file 213/2001: imagesTr/PARTIAL_0212_0000.nii.gz
# Copying file 214/2001: imagesTr/PARTIAL_0213_0000.nii.gz
# Copying file 215/2001: imagesTr/PARTIAL_0214_0000.nii.gz
# Completed 215/2001 files (10.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=215, batch_size=5)
#
#
# Processing batch 44: files 216-220 of 2001
# Copying file 216/2001: imagesTr/PARTIAL_0215_0000.nii.gz
# Copying file 217/2001: imagesTr/PARTIAL_0216_0000.nii.gz
# Copying file 218/2001: imagesTr/PARTIAL_0217_0000.nii.gz
# Copying file 219/2001: imagesTr/PARTIAL_0218_0000.nii.gz
# Copying file 220/2001: imagesTr/PARTIAL_0219_0000.nii.gz
# Completed 220/2001 files (11.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=220, batch_size=5)
#
#
# Processing batch 45: files 221-225 of 2001
# Copying file 221/2001: imagesTr/PARTIAL_0220_0000.nii.gz
# Copying file 222/2001: imagesTr/PARTIAL_0221_0000.nii.gz
# Copying file 223/2001: imagesTr/PARTIAL_0222_0000.nii.gz
# Copying file 224/2001: imagesTr/PARTIAL_0223_0000.nii.gz
# Copying file 225/2001: imagesTr/PARTIAL_0224_0000.nii.gz
# Completed 225/2001 files (11.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=225, batch_size=5)
#
#
# Processing batch 46: files 226-230 of 2001
# Copying file 226/2001: imagesTr/PARTIAL_0225_0000.nii.gz
# Copying file 227/2001: imagesTr/PARTIAL_0226_0000.nii.gz
# Copying file 228/2001: imagesTr/PARTIAL_0227_0000.nii.gz
# Copying file 229/2001: imagesTr/PARTIAL_0228_0000.nii.gz
# Copying file 230/2001: imagesTr/PARTIAL_0229_0000.nii.gz
# Completed 230/2001 files (11.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=230, batch_size=5)
#
#
# Processing batch 47: files 231-235 of 2001
# Copying file 231/2001: imagesTr/PARTIAL_0230_0000.nii.gz
# Copying file 232/2001: imagesTr/PARTIAL_0231_0000.nii.gz
# Copying file 233/2001: imagesTr/PARTIAL_0232_0000.nii.gz
# Copying file 234/2001: imagesTr/PARTIAL_0233_0000.nii.gz
# Copying file 235/2001: imagesTr/PARTIAL_0234_0000.nii.gz
# Completed 235/2001 files (11.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=235, batch_size=5)
#
#
# Processing batch 48: files 236-240 of 2001
# Copying file 236/2001: imagesTr/PARTIAL_0235_0000.nii.gz
# Copying file 237/2001: imagesTr/PARTIAL_0236_0000.nii.gz
# Copying file 238/2001: imagesTr/PARTIAL_0237_0000.nii.gz
# Copying file 239/2001: imagesTr/PARTIAL_0238_0000.nii.gz
# Copying file 240/2001: imagesTr/PARTIAL_0239_0000.nii.gz
# Completed 240/2001 files (12.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=240, batch_size=5)
#
#
# Processing batch 49: files 241-245 of 2001
# Copying file 241/2001: imagesTr/PARTIAL_0240_0000.nii.gz
# Copying file 242/2001: imagesTr/PARTIAL_0241_0000.nii.gz
# Copying file 243/2001: imagesTr/PARTIAL_0242_0000.nii.gz
# Copying file 244/2001: imagesTr/PARTIAL_0243_0000.nii.gz
# Copying file 245/2001: imagesTr/PARTIAL_0244_0000.nii.gz
# Completed 245/2001 files (12.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=245, batch_size=5)
#
#
# Processing batch 50: files 246-250 of 2001
# Copying file 246/2001: imagesTr/PARTIAL_0245_0000.nii.gz
# Copying file 247/2001: imagesTr/PARTIAL_0246_0000.nii.gz
# Copying file 248/2001: imagesTr/PARTIAL_0247_0000.nii.gz
# Copying file 249/2001: imagesTr/PARTIAL_0248_0000.nii.gz
# Copying file 250/2001: imagesTr/PARTIAL_0249_0000.nii.gz
# Completed 250/2001 files (12.5%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=250, batch_size=5)
#
#
# Processing batch 51: files 251-255 of 2001
# Copying file 251/2001: imagesTr/PARTIAL_0250_0000.nii.gz
# Copying file 252/2001: imagesTr/PARTIAL_0251_0000.nii.gz
# Copying file 253/2001: imagesTr/PARTIAL_0252_0000.nii.gz
# Copying file 254/2001: imagesTr/PARTIAL_0253_0000.nii.gz
# Copying file 255/2001: imagesTr/PARTIAL_0254_0000.nii.gz
# Completed 255/2001 files (12.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=255, batch_size=5)
#
#
# Processing batch 52: files 256-260 of 2001
# Copying file 256/2001: imagesTr/PARTIAL_0255_0000.nii.gz
# Copying file 257/2001: imagesTr/PARTIAL_0256_0000.nii.gz
# Copying file 258/2001: imagesTr/PARTIAL_0257_0000.nii.gz
# Copying file 259/2001: imagesTr/PARTIAL_0258_0000.nii.gz
# Copying file 260/2001: imagesTr/PARTIAL_0259_0000.nii.gz
# Completed 260/2001 files (13.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=260, batch_size=5)
#
#
# Processing batch 53: files 261-265 of 2001
# Copying file 261/2001: imagesTr/PARTIAL_0260_0000.nii.gz
# Copying file 262/2001: imagesTr/PARTIAL_0261_0000.nii.gz
# Copying file 263/2001: imagesTr/PARTIAL_0262_0000.nii.gz
# Copying file 264/2001: imagesTr/PARTIAL_0263_0000.nii.gz
# Copying file 265/2001: imagesTr/PARTIAL_0264_0000.nii.gz
# Completed 265/2001 files (13.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=265, batch_size=5)
#
#
# Processing batch 54: files 266-270 of 2001
# Copying file 266/2001: imagesTr/PARTIAL_0265_0000.nii.gz
# Copying file 267/2001: imagesTr/PARTIAL_0266_0000.nii.gz
# Copying file 268/2001: imagesTr/PARTIAL_0267_0000.nii.gz
# Copying file 269/2001: imagesTr/PARTIAL_0268_0000.nii.gz
# Copying file 270/2001: imagesTr/PARTIAL_0269_0000.nii.gz
# Completed 270/2001 files (13.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=270, batch_size=5)
#
#
# Processing batch 55: files 271-275 of 2001
# Copying file 271/2001: imagesTr/PARTIAL_0270_0000.nii.gz
# Copying file 272/2001: imagesTr/PARTIAL_0271_0000.nii.gz
# Copying file 273/2001: imagesTr/PARTIAL_0272_0000.nii.gz
# Copying file 274/2001: imagesTr/PARTIAL_0273_0000.nii.gz
# Copying file 275/2001: imagesTr/PARTIAL_0274_0000.nii.gz
# Completed 275/2001 files (13.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=275, batch_size=5)
#
#
# Processing batch 56: files 276-280 of 2001
# Copying file 276/2001: imagesTr/PARTIAL_0275_0000.nii.gz
# Copying file 277/2001: imagesTr/PARTIAL_0276_0000.nii.gz
# Copying file 278/2001: imagesTr/PARTIAL_0277_0000.nii.gz
# Copying file 279/2001: imagesTr/PARTIAL_0278_0000.nii.gz
# Copying file 280/2001: imagesTr/PARTIAL_0279_0000.nii.gz
# Completed 280/2001 files (14.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=280, batch_size=5)
#
#
# Processing batch 57: files 281-285 of 2001
# Copying file 281/2001: imagesTr/PARTIAL_0280_0000.nii.gz
# Copying file 282/2001: imagesTr/PARTIAL_0281_0000.nii.gz
# Copying file 283/2001: imagesTr/PARTIAL_0282_0000.nii.gz
# Copying file 284/2001: imagesTr/PARTIAL_0283_0000.nii.gz
# Copying file 285/2001: imagesTr/PARTIAL_0284_0000.nii.gz
# Completed 285/2001 files (14.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=285, batch_size=5)
#
#
# Processing batch 58: files 286-290 of 2001
# Copying file 286/2001: imagesTr/PARTIAL_0285_0000.nii.gz
# Copying file 287/2001: imagesTr/PARTIAL_0286_0000.nii.gz
# Copying file 288/2001: imagesTr/PARTIAL_0287_0000.nii.gz
# Copying file 289/2001: imagesTr/PARTIAL_0288_0000.nii.gz
# Copying file 290/2001: imagesTr/PARTIAL_0289_0000.nii.gz
# Completed 290/2001 files (14.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=290, batch_size=5)
#
#
# Processing batch 59: files 291-295 of 2001
# Copying file 291/2001: imagesTr/PARTIAL_0290_0000.nii.gz
# Copying file 292/2001: imagesTr/PARTIAL_0291_0000.nii.gz
# Copying file 293/2001: imagesTr/PARTIAL_0292_0000.nii.gz
# Copying file 294/2001: imagesTr/PARTIAL_0293_0000.nii.gz
# Copying file 295/2001: imagesTr/PARTIAL_0294_0000.nii.gz
# Completed 295/2001 files (14.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=295, batch_size=5)
#
#
# Processing batch 60: files 296-300 of 2001
# Copying file 296/2001: imagesTr/PARTIAL_0295_0000.nii.gz
# Copying file 297/2001: imagesTr/PARTIAL_0296_0000.nii.gz
# Copying file 298/2001: imagesTr/PARTIAL_0297_0000.nii.gz
# Copying file 299/2001: imagesTr/PARTIAL_0298_0000.nii.gz
# Copying file 300/2001: imagesTr/PARTIAL_0299_0000.nii.gz
# Completed 300/2001 files (15.0%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=300, batch_size=5)
#
#
# Processing batch 61: files 301-305 of 2001
# Copying file 301/2001: imagesTr/PARTIAL_0300_0000.nii.gz
# Copying file 302/2001: imagesTr/PARTIAL_0301_0000.nii.gz
# Copying file 303/2001: imagesTr/PARTIAL_0302_0000.nii.gz
# Copying file 304/2001: imagesTr/PARTIAL_0303_0000.nii.gz
# Copying file 305/2001: imagesTr/PARTIAL_0304_0000.nii.gz
# Completed 305/2001 files (15.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=305, batch_size=5)
#
#
# Processing batch 62: files 306-310 of 2001
# Copying file 306/2001: imagesTr/PARTIAL_0305_0000.nii.gz
# Copying file 307/2001: imagesTr/PARTIAL_0306_0000.nii.gz
# Copying file 308/2001: imagesTr/PARTIAL_0307_0000.nii.gz
# Copying file 309/2001: imagesTr/PARTIAL_0308_0000.nii.gz
# Copying file 310/2001: imagesTr/PARTIAL_0309_0000.nii.gz
# Completed 310/2001 files (15.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=310, batch_size=5)
#
#
# Processing batch 63: files 311-315 of 2001
# Copying file 311/2001: imagesTr/PARTIAL_0310_0000.nii.gz
# Copying file 312/2001: imagesTr/PARTIAL_0311_0000.nii.gz
# Copying file 313/2001: imagesTr/PARTIAL_0312_0000.nii.gz
# Copying file 314/2001: imagesTr/PARTIAL_0313_0000.nii.gz
# Copying file 315/2001: imagesTr/PARTIAL_0314_0000.nii.gz
# Completed 315/2001 files (15.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=315, batch_size=5)
#
#
# Processing batch 64: files 316-320 of 2001
# Copying file 316/2001: imagesTr/PARTIAL_0315_0000.nii.gz
# Copying file 317/2001: imagesTr/PARTIAL_0316_0000.nii.gz
# Copying file 318/2001: imagesTr/PARTIAL_0317_0000.nii.gz
# Copying file 319/2001: imagesTr/PARTIAL_0318_0000.nii.gz
# Copying file 320/2001: imagesTr/PARTIAL_0319_0000.nii.gz
# Completed 320/2001 files (16.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=320, batch_size=5)
#
#
# Processing batch 65: files 321-325 of 2001
# Copying file 321/2001: imagesTr/PARTIAL_0320_0000.nii.gz
# Copying file 322/2001: imagesTr/PARTIAL_0321_0000.nii.gz
# Copying file 323/2001: imagesTr/PARTIAL_0322_0000.nii.gz
# Copying file 324/2001: imagesTr/PARTIAL_0323_0000.nii.gz
# Copying file 325/2001: imagesTr/PARTIAL_0324_0000.nii.gz
# Completed 325/2001 files (16.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=325, batch_size=5)
#
#
# Processing batch 66: files 326-330 of 2001
# Copying file 326/2001: imagesTr/PARTIAL_0325_0000.nii.gz
# Copying file 327/2001: imagesTr/PARTIAL_0326_0000.nii.gz
# Copying file 328/2001: imagesTr/PARTIAL_0327_0000.nii.gz
# Copying file 329/2001: imagesTr/PARTIAL_0328_0000.nii.gz
# Copying file 330/2001: imagesTr/PARTIAL_0329_0000.nii.gz
# Completed 330/2001 files (16.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=330, batch_size=5)
#
#
# Processing batch 67: files 331-335 of 2001
# Copying file 331/2001: imagesTr/PARTIAL_0330_0000.nii.gz
# Copying file 332/2001: imagesTr/PARTIAL_0331_0000.nii.gz
# Copying file 333/2001: imagesTr/PARTIAL_0332_0000.nii.gz
# Copying file 334/2001: imagesTr/PARTIAL_0333_0000.nii.gz
# Copying file 335/2001: imagesTr/PARTIAL_0334_0000.nii.gz
# Completed 335/2001 files (16.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=335, batch_size=5)
#
#
# Processing batch 68: files 336-340 of 2001
# Copying file 336/2001: imagesTr/PARTIAL_0335_0000.nii.gz
# Copying file 337/2001: imagesTr/PARTIAL_0336_0000.nii.gz
# Copying file 338/2001: imagesTr/PARTIAL_0337_0000.nii.gz
# Copying file 339/2001: imagesTr/PARTIAL_0338_0000.nii.gz
# Copying file 340/2001: imagesTr/PARTIAL_0339_0000.nii.gz
# Completed 340/2001 files (17.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=340, batch_size=5)
#
#
# Processing batch 69: files 341-345 of 2001
# Copying file 341/2001: imagesTr/PARTIAL_0340_0000.nii.gz
# Copying file 342/2001: imagesTr/PARTIAL_0341_0000.nii.gz
# Copying file 343/2001: imagesTr/PARTIAL_0342_0000.nii.gz
# Copying file 344/2001: imagesTr/PARTIAL_0343_0000.nii.gz
# Copying file 345/2001: imagesTr/PARTIAL_0344_0000.nii.gz
# Completed 345/2001 files (17.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=345, batch_size=5)
#
#
# Processing batch 70: files 346-350 of 2001
# Copying file 346/2001: imagesTr/PARTIAL_0345_0000.nii.gz
# Copying file 347/2001: imagesTr/PARTIAL_0346_0000.nii.gz
# Copying file 348/2001: imagesTr/PARTIAL_0347_0000.nii.gz
# Copying file 349/2001: imagesTr/PARTIAL_0348_0000.nii.gz
# Copying file 350/2001: imagesTr/PARTIAL_0349_0000.nii.gz
# Completed 350/2001 files (17.5%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=350, batch_size=5)
#
#
# Processing batch 71: files 351-355 of 2001
# Copying file 351/2001: imagesTr/PARTIAL_0350_0000.nii.gz
# Copying file 352/2001: imagesTr/PARTIAL_0351_0000.nii.gz
# Copying file 353/2001: imagesTr/PARTIAL_0352_0000.nii.gz
# Copying file 354/2001: imagesTr/PARTIAL_0353_0000.nii.gz
# Copying file 355/2001: imagesTr/PARTIAL_0354_0000.nii.gz
# Completed 355/2001 files (17.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=355, batch_size=5)
#
#
# Processing batch 72: files 356-360 of 2001
# Copying file 356/2001: imagesTr/PARTIAL_0355_0000.nii.gz
# Copying file 357/2001: imagesTr/PARTIAL_0356_0000.nii.gz
# Copying file 358/2001: imagesTr/PARTIAL_0357_0000.nii.gz
# Copying file 359/2001: imagesTr/PARTIAL_0358_0000.nii.gz
# Copying file 360/2001: imagesTr/PARTIAL_0359_0000.nii.gz
# Completed 360/2001 files (18.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=360, batch_size=5)
#
#
# Processing batch 73: files 361-365 of 2001
# Copying file 361/2001: imagesTr/PARTIAL_0360_0000.nii.gz
# Copying file 362/2001: imagesTr/PARTIAL_0361_0000.nii.gz
# Copying file 363/2001: imagesTr/PARTIAL_0362_0000.nii.gz
# Copying file 364/2001: imagesTr/PARTIAL_0363_0000.nii.gz
# Copying file 365/2001: imagesTr/PARTIAL_0364_0000.nii.gz
# Completed 365/2001 files (18.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=365, batch_size=5)
#
#
# Processing batch 74: files 366-370 of 2001
# Copying file 366/2001: imagesTr/PARTIAL_0365_0000.nii.gz
# Copying file 367/2001: imagesTr/PARTIAL_0366_0000.nii.gz
# Copying file 368/2001: imagesTr/PARTIAL_0367_0000.nii.gz
# Copying file 369/2001: imagesTr/PARTIAL_0368_0000.nii.gz
# Copying file 370/2001: imagesTr/PARTIAL_0369_0000.nii.gz
# Completed 370/2001 files (18.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=370, batch_size=5)
#
#
# Processing batch 75: files 371-375 of 2001
# Copying file 371/2001: imagesTr/PARTIAL_0370_0000.nii.gz
# Copying file 372/2001: imagesTr/PARTIAL_0371_0000.nii.gz
# Copying file 373/2001: imagesTr/PARTIAL_0372_0000.nii.gz
# Copying file 374/2001: imagesTr/PARTIAL_0373_0000.nii.gz
# Copying file 375/2001: imagesTr/PARTIAL_0374_0000.nii.gz
# Completed 375/2001 files (18.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=375, batch_size=5)
#
#
# Processing batch 76: files 376-380 of 2001
# Copying file 376/2001: imagesTr/PARTIAL_0375_0000.nii.gz
# Copying file 377/2001: imagesTr/PARTIAL_0376_0000.nii.gz
# Copying file 378/2001: imagesTr/PARTIAL_0377_0000.nii.gz
# Copying file 379/2001: imagesTr/PARTIAL_0378_0000.nii.gz
# Copying file 380/2001: imagesTr/PARTIAL_0379_0000.nii.gz
# Completed 380/2001 files (19.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=380, batch_size=5)
#
#
# Processing batch 77: files 381-385 of 2001
# Copying file 381/2001: imagesTr/PARTIAL_0380_0000.nii.gz
# Copying file 382/2001: imagesTr/PARTIAL_0381_0000.nii.gz
# Copying file 383/2001: imagesTr/PARTIAL_0382_0000.nii.gz
# Copying file 384/2001: imagesTr/PARTIAL_0383_0000.nii.gz
# Copying file 385/2001: imagesTr/PARTIAL_0384_0000.nii.gz
# Completed 385/2001 files (19.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=385, batch_size=5)
#
#
# Processing batch 78: files 386-390 of 2001
# Copying file 386/2001: imagesTr/PARTIAL_0385_0000.nii.gz
# Copying file 387/2001: imagesTr/PARTIAL_0386_0000.nii.gz
# Copying file 388/2001: imagesTr/PARTIAL_0387_0000.nii.gz
# Copying file 389/2001: imagesTr/PARTIAL_0388_0000.nii.gz
# Copying file 390/2001: imagesTr/PARTIAL_0389_0000.nii.gz
# Completed 390/2001 files (19.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=390, batch_size=5)
#
#
# Processing batch 79: files 391-395 of 2001
# Copying file 391/2001: imagesTr/PARTIAL_0390_0000.nii.gz
# Copying file 392/2001: imagesTr/PARTIAL_0391_0000.nii.gz
# Copying file 393/2001: imagesTr/PARTIAL_0392_0000.nii.gz
# Copying file 394/2001: imagesTr/PARTIAL_0393_0000.nii.gz
# Copying file 395/2001: imagesTr/PARTIAL_0394_0000.nii.gz
# Completed 395/2001 files (19.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=395, batch_size=5)
#
#
# Processing batch 80: files 396-400 of 2001
# Copying file 396/2001: imagesTr/PARTIAL_0395_0000.nii.gz
# Copying file 397/2001: imagesTr/PARTIAL_0396_0000.nii.gz
# Copying file 398/2001: imagesTr/PARTIAL_0397_0000.nii.gz
# Copying file 399/2001: imagesTr/PARTIAL_0398_0000.nii.gz
# Copying file 400/2001: imagesTr/PARTIAL_0399_0000.nii.gz
# Completed 400/2001 files (20.0%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=400, batch_size=5)
#
#
# Processing batch 81: files 401-405 of 2001
# Copying file 401/2001: imagesTr/PARTIAL_0400_0000.nii.gz
# Copying file 402/2001: imagesTr/PARTIAL_0401_0000.nii.gz
# Copying file 403/2001: imagesTr/PARTIAL_0402_0000.nii.gz
# Copying file 404/2001: imagesTr/PARTIAL_0403_0000.nii.gz
# Copying file 405/2001: imagesTr/PARTIAL_0404_0000.nii.gz
# Completed 405/2001 files (20.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=405, batch_size=5)
#
#
# Processing batch 82: files 406-410 of 2001
# Copying file 406/2001: imagesTr/PARTIAL_0405_0000.nii.gz
# Copying file 407/2001: imagesTr/PARTIAL_0406_0000.nii.gz
# Copying file 408/2001: imagesTr/PARTIAL_0407_0000.nii.gz
# Copying file 409/2001: imagesTr/PARTIAL_0408_0000.nii.gz
# Copying file 410/2001: imagesTr/PARTIAL_0409_0000.nii.gz
# Completed 410/2001 files (20.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=410, batch_size=5)
#
#
# Processing batch 83: files 411-415 of 2001
# Copying file 411/2001: imagesTr/PARTIAL_0410_0000.nii.gz
# Copying file 412/2001: imagesTr/PARTIAL_0411_0000.nii.gz
# Copying file 413/2001: imagesTr/PARTIAL_0412_0000.nii.gz
# Copying file 414/2001: imagesTr/PARTIAL_0413_0000.nii.gz
# Copying file 415/2001: imagesTr/PARTIAL_0414_0000.nii.gz
# Completed 415/2001 files (20.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=415, batch_size=5)
#
#
# Processing batch 84: files 416-420 of 2001
# Copying file 416/2001: imagesTr/PARTIAL_0415_0000.nii.gz
# Copying file 417/2001: imagesTr/PARTIAL_0416_0000.nii.gz
# Copying file 418/2001: imagesTr/PARTIAL_0417_0000.nii.gz
# Copying file 419/2001: imagesTr/PARTIAL_0418_0000.nii.gz
# Copying file 420/2001: imagesTr/PARTIAL_0419_0000.nii.gz
# Completed 420/2001 files (21.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=420, batch_size=5)
#
#
# Processing batch 85: files 421-425 of 2001
# Copying file 421/2001: imagesTr/PARTIAL_0420_0000.nii.gz
# Copying file 422/2001: imagesTr/PARTIAL_0421_0000.nii.gz
# Copying file 423/2001: imagesTr/PARTIAL_0422_0000.nii.gz
# Copying file 424/2001: imagesTr/PARTIAL_0423_0000.nii.gz
# Copying file 425/2001: imagesTr/PARTIAL_0424_0000.nii.gz
# Completed 425/2001 files (21.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=425, batch_size=5)
#
#
# Processing batch 86: files 426-430 of 2001
# Copying file 426/2001: imagesTr/PARTIAL_0425_0000.nii.gz
# Copying file 427/2001: imagesTr/PARTIAL_0426_0000.nii.gz
# Copying file 428/2001: imagesTr/PARTIAL_0427_0000.nii.gz
# Copying file 429/2001: imagesTr/PARTIAL_0428_0000.nii.gz
# Copying file 430/2001: imagesTr/PARTIAL_0429_0000.nii.gz
# Completed 430/2001 files (21.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=430, batch_size=5)
#
#
# Processing batch 87: files 431-435 of 2001
# Copying file 431/2001: imagesTr/PARTIAL_0430_0000.nii.gz
# Copying file 432/2001: imagesTr/PARTIAL_0431_0000.nii.gz
# Copying file 433/2001: imagesTr/PARTIAL_0432_0000.nii.gz
# Copying file 434/2001: imagesTr/PARTIAL_0433_0000.nii.gz
# Copying file 435/2001: imagesTr/PARTIAL_0434_0000.nii.gz
# Completed 435/2001 files (21.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=435, batch_size=5)
#
#
# Processing batch 88: files 436-440 of 2001
# Copying file 436/2001: imagesTr/PARTIAL_0435_0000.nii.gz
# Copying file 437/2001: imagesTr/PARTIAL_0436_0000.nii.gz
# Copying file 438/2001: imagesTr/PARTIAL_0437_0000.nii.gz
# Copying file 439/2001: imagesTr/PARTIAL_0439_0000.nii.gz
# Copying file 440/2001: imagesTr/PARTIAL_0440_0000.nii.gz
# Completed 440/2001 files (22.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=440, batch_size=5)
#
#
# Processing batch 89: files 441-445 of 2001
# Copying file 441/2001: imagesTr/PARTIAL_0441_0000.nii.gz
# Copying file 442/2001: imagesTr/PARTIAL_0442_0000.nii.gz
# Copying file 443/2001: imagesTr/PARTIAL_0443_0000.nii.gz
# Copying file 444/2001: imagesTr/PARTIAL_0444_0000.nii.gz
# Copying file 445/2001: imagesTr/PARTIAL_0445_0000.nii.gz
# Completed 445/2001 files (22.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=445, batch_size=5)
#
#
# Processing batch 90: files 446-450 of 2001
# Copying file 446/2001: imagesTr/PARTIAL_0446_0000.nii.gz
# Copying file 447/2001: imagesTr/PARTIAL_0447_0000.nii.gz
# Copying file 448/2001: imagesTr/PARTIAL_0448_0000.nii.gz
# Copying file 449/2001: imagesTr/PARTIAL_0449_0000.nii.gz
# Copying file 450/2001: imagesTr/PARTIAL_0450_0000.nii.gz
# Completed 450/2001 files (22.5%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=450, batch_size=5)
#
#
# Processing batch 91: files 451-455 of 2001
# Copying file 451/2001: imagesTr/PARTIAL_0451_0000.nii.gz
# Copying file 452/2001: imagesTr/PARTIAL_0452_0000.nii.gz
# Copying file 453/2001: imagesTr/PARTIAL_0453_0000.nii.gz
# Copying file 454/2001: imagesTr/PARTIAL_0454_0000.nii.gz
# Copying file 455/2001: imagesTr/PARTIAL_0455_0000.nii.gz
# Completed 455/2001 files (22.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=455, batch_size=5)
#
#
# Processing batch 92: files 456-460 of 2001
# Copying file 456/2001: imagesTr/PARTIAL_0456_0000.nii.gz
# Copying file 457/2001: imagesTr/PARTIAL_0457_0000.nii.gz
# Copying file 458/2001: imagesTr/PARTIAL_0458_0000.nii.gz
# Copying file 459/2001: imagesTr/PARTIAL_0459_0000.nii.gz
# Copying file 460/2001: imagesTr/PARTIAL_0460_0000.nii.gz
# Completed 460/2001 files (23.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=460, batch_size=5)
#
#
# Processing batch 93: files 461-465 of 2001
# Copying file 461/2001: imagesTr/PARTIAL_0461_0000.nii.gz
# Copying file 462/2001: imagesTr/PARTIAL_0462_0000.nii.gz
# Copying file 463/2001: imagesTr/PARTIAL_0463_0000.nii.gz
# Copying file 464/2001: imagesTr/PARTIAL_0464_0000.nii.gz
# Copying file 465/2001: imagesTr/PARTIAL_0465_0000.nii.gz
# Completed 465/2001 files (23.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=465, batch_size=5)
#
#
# Processing batch 94: files 466-470 of 2001
# Copying file 466/2001: imagesTr/PARTIAL_0466_0000.nii.gz
# Copying file 467/2001: imagesTr/PARTIAL_0467_0000.nii.gz
# Copying file 468/2001: imagesTr/PARTIAL_0468_0000.nii.gz
# ...
# Copying file 1878/2001: labelsTr/PARTIAL_0761.nii.gz
# Copying file 1879/2001: labelsTr/PARTIAL_0763.nii.gz
# Copying file 1880/2001: labelsTr/PARTIAL_0765.nii.gz
# Completed 1880/2001 files (94.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1880, batch_size=5)
#
#
# Processing batch 377: files 1881-1885 of 2001
# Copying file 1881/2001: labelsTr/PARTIAL_0767.nii.gz
# Copying file 1882/2001: labelsTr/PARTIAL_0769.nii.gz
# Copying file 1883/2001: labelsTr/PARTIAL_0771.nii.gz
# Copying file 1884/2001: labelsTr/PARTIAL_0773.nii.gz
# Copying file 1885/2001: labelsTr/PARTIAL_0776.nii.gz
# Completed 1885/2001 files (94.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1885, batch_size=5)
#
#
# Processing batch 378: files 1886-1890 of 2001
# Copying file 1886/2001: labelsTr/PARTIAL_0777.nii.gz
# Copying file 1887/2001: labelsTr/PARTIAL_0779.nii.gz
# Copying file 1888/2001: labelsTr/PARTIAL_0780.nii.gz
# Copying file 1889/2001: labelsTr/PARTIAL_0783.nii.gz
# Copying file 1890/2001: labelsTr/PARTIAL_0784.nii.gz
# Completed 1890/2001 files (94.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1890, batch_size=5)
#
#
# Processing batch 379: files 1891-1895 of 2001
# Copying file 1891/2001: labelsTr/PARTIAL_0787.nii.gz
# Copying file 1892/2001: labelsTr/PARTIAL_0788.nii.gz
# Copying file 1893/2001: labelsTr/PARTIAL_0792.nii.gz
# Copying file 1894/2001: labelsTr/PARTIAL_0794.nii.gz
# Copying file 1895/2001: labelsTr/PARTIAL_0796.nii.gz
# Completed 1895/2001 files (94.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1895, batch_size=5)
#
#
# Processing batch 380: files 1896-1900 of 2001
# Copying file 1896/2001: labelsTr/PARTIAL_0797.nii.gz
# Copying file 1897/2001: labelsTr/PARTIAL_0798.nii.gz
# Copying file 1898/2001: labelsTr/PARTIAL_0799.nii.gz
# Copying file 1899/2001: labelsTr/PARTIAL_0800.nii.gz
# Copying file 1900/2001: labelsTr/PARTIAL_0801.nii.gz
# Completed 1900/2001 files (95.0%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1900, batch_size=5)
#
#
# Processing batch 381: files 1901-1905 of 2001
# Copying file 1901/2001: labelsTr/PARTIAL_0804.nii.gz
# Copying file 1902/2001: labelsTr/PARTIAL_0805.nii.gz
# Copying file 1903/2001: labelsTr/PARTIAL_0808.nii.gz
# Copying file 1904/2001: labelsTr/PARTIAL_0809.nii.gz
# Copying file 1905/2001: labelsTr/PARTIAL_0812.nii.gz
# Completed 1905/2001 files (95.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1905, batch_size=5)
#
#
# Processing batch 382: files 1906-1910 of 2001
# Copying file 1906/2001: labelsTr/PARTIAL_0813.nii.gz
# Copying file 1907/2001: labelsTr/PARTIAL_0817.nii.gz
# Copying file 1908/2001: labelsTr/PARTIAL_0820.nii.gz
# Copying file 1909/2001: labelsTr/PARTIAL_0823.nii.gz
# Copying file 1910/2001: labelsTr/PARTIAL_0826.nii.gz
# Completed 1910/2001 files (95.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1910, batch_size=5)
#
#
# Processing batch 383: files 1911-1915 of 2001
# Copying file 1911/2001: labelsTr/PARTIAL_0828.nii.gz
# Copying file 1912/2001: labelsTr/PARTIAL_0829.nii.gz
# Copying file 1913/2001: labelsTr/PARTIAL_0830.nii.gz
# Copying file 1914/2001: labelsTr/PARTIAL_0832.nii.gz
# Copying file 1915/2001: labelsTr/PARTIAL_0833.nii.gz
# Completed 1915/2001 files (95.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1915, batch_size=5)
#
#
# Processing batch 384: files 1916-1920 of 2001
# Copying file 1916/2001: labelsTr/PARTIAL_0834.nii.gz
# Copying file 1917/2001: labelsTr/PARTIAL_0835.nii.gz
# Copying file 1918/2001: labelsTr/PARTIAL_0837.nii.gz
# Copying file 1919/2001: labelsTr/PARTIAL_0838.nii.gz
# Copying file 1920/2001: labelsTr/PARTIAL_0843.nii.gz
# Completed 1920/2001 files (96.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1920, batch_size=5)
#
#
# Processing batch 385: files 1921-1925 of 2001
# Copying file 1921/2001: labelsTr/PARTIAL_0846.nii.gz
# Copying file 1922/2001: labelsTr/PARTIAL_0853.nii.gz
# Copying file 1923/2001: labelsTr/PARTIAL_0854.nii.gz
# Copying file 1924/2001: labelsTr/PARTIAL_0855.nii.gz
# Copying file 1925/2001: labelsTr/PARTIAL_0857.nii.gz
# Completed 1925/2001 files (96.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1925, batch_size=5)
#
#
# Processing batch 386: files 1926-1930 of 2001
# Copying file 1926/2001: labelsTr/PARTIAL_0858.nii.gz
# Copying file 1927/2001: labelsTr/PARTIAL_0860.nii.gz
# Copying file 1928/2001: labelsTr/PARTIAL_0861.nii.gz
# Copying file 1929/2001: labelsTr/PARTIAL_0866.nii.gz
# Copying file 1930/2001: labelsTr/PARTIAL_0867.nii.gz
# Completed 1930/2001 files (96.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1930, batch_size=5)
#
#
# Processing batch 387: files 1931-1935 of 2001
# Copying file 1931/2001: labelsTr/PARTIAL_0869.nii.gz
# Copying file 1932/2001: labelsTr/PARTIAL_0871.nii.gz
# Copying file 1933/2001: labelsTr/PARTIAL_0873.nii.gz
# Copying file 1934/2001: labelsTr/PARTIAL_0874.nii.gz
# Copying file 1935/2001: labelsTr/PARTIAL_0876.nii.gz
# Completed 1935/2001 files (96.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1935, batch_size=5)
#
#
# Processing batch 388: files 1936-1940 of 2001
# Copying file 1936/2001: labelsTr/PARTIAL_0879.nii.gz
# Copying file 1937/2001: labelsTr/PARTIAL_0881.nii.gz
# Copying file 1938/2001: labelsTr/PARTIAL_0882.nii.gz
# Copying file 1939/2001: labelsTr/PARTIAL_0885.nii.gz
# Copying file 1940/2001: labelsTr/PARTIAL_0893.nii.gz
# Completed 1940/2001 files (97.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1940, batch_size=5)
#
#
# Processing batch 389: files 1941-1945 of 2001
# Copying file 1941/2001: labelsTr/PARTIAL_0895.nii.gz
# Copying file 1942/2001: labelsTr/PARTIAL_0897.nii.gz
# Copying file 1943/2001: labelsTr/PARTIAL_0899.nii.gz
# Copying file 1944/2001: labelsTr/PARTIAL_0900.nii.gz
# Copying file 1945/2001: labelsTr/PARTIAL_0902.nii.gz
# Completed 1945/2001 files (97.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1945, batch_size=5)
#
#
# Processing batch 390: files 1946-1950 of 2001
# Copying file 1946/2001: labelsTr/PARTIAL_0903.nii.gz
# Copying file 1947/2001: labelsTr/PARTIAL_0904.nii.gz
# Copying file 1948/2001: labelsTr/PARTIAL_0905.nii.gz
# Copying file 1949/2001: labelsTr/PARTIAL_0908.nii.gz
# Copying file 1950/2001: labelsTr/PARTIAL_0911.nii.gz
# Completed 1950/2001 files (97.5%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1950, batch_size=5)
#
#
# Processing batch 391: files 1951-1955 of 2001
# Copying file 1951/2001: labelsTr/PARTIAL_0912.nii.gz
# Copying file 1952/2001: labelsTr/PARTIAL_0916.nii.gz
# Copying file 1953/2001: labelsTr/PARTIAL_0919.nii.gz
# Copying file 1954/2001: labelsTr/PARTIAL_0920.nii.gz
# Copying file 1955/2001: labelsTr/PARTIAL_0921.nii.gz
# Completed 1955/2001 files (97.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1955, batch_size=5)
#
#
# Processing batch 392: files 1956-1960 of 2001
# Copying file 1956/2001: labelsTr/PARTIAL_0922.nii.gz
# Copying file 1957/2001: labelsTr/PARTIAL_0923.nii.gz
# Copying file 1958/2001: labelsTr/PARTIAL_0925.nii.gz
# Copying file 1959/2001: labelsTr/PARTIAL_0926.nii.gz
# Copying file 1960/2001: labelsTr/PARTIAL_0930.nii.gz
# Completed 1960/2001 files (98.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1960, batch_size=5)
#
#
# Processing batch 393: files 1961-1965 of 2001
# Copying file 1961/2001: labelsTr/PARTIAL_0931.nii.gz
# Copying file 1962/2001: labelsTr/PARTIAL_0932.nii.gz
# Copying file 1963/2001: labelsTr/PARTIAL_0936.nii.gz
# Copying file 1964/2001: labelsTr/PARTIAL_0939.nii.gz
# Copying file 1965/2001: labelsTr/PARTIAL_0940.nii.gz
# Completed 1965/2001 files (98.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1965, batch_size=5)
#
#
# Processing batch 394: files 1966-1970 of 2001
# Copying file 1966/2001: labelsTr/PARTIAL_0942.nii.gz
# Copying file 1967/2001: labelsTr/PARTIAL_0943.nii.gz
# Copying file 1968/2001: labelsTr/PARTIAL_0944.nii.gz
# Copying file 1969/2001: labelsTr/PARTIAL_0945.nii.gz
# Copying file 1970/2001: labelsTr/PARTIAL_0947.nii.gz
# Completed 1970/2001 files (98.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1970, batch_size=5)
#
#
# Processing batch 395: files 1971-1975 of 2001
# Copying file 1971/2001: labelsTr/PARTIAL_0949.nii.gz
# Copying file 1972/2001: labelsTr/PARTIAL_0953.nii.gz
# Copying file 1973/2001: labelsTr/PARTIAL_0956.nii.gz
# Copying file 1974/2001: labelsTr/PARTIAL_0957.nii.gz
# Copying file 1975/2001: labelsTr/PARTIAL_0958.nii.gz
# Completed 1975/2001 files (98.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1975, batch_size=5)
#
#
# Processing batch 396: files 1976-1980 of 2001
# Copying file 1976/2001: labelsTr/PARTIAL_0959.nii.gz
# Copying file 1977/2001: labelsTr/PARTIAL_0964.nii.gz
# Copying file 1978/2001: labelsTr/PARTIAL_0967.nii.gz
# Copying file 1979/2001: labelsTr/PARTIAL_0968.nii.gz
# Copying file 1980/2001: labelsTr/PARTIAL_0969.nii.gz
# Completed 1980/2001 files (99.0%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1980, batch_size=5)
#
#
# Processing batch 397: files 1981-1985 of 2001
# Copying file 1981/2001: labelsTr/PARTIAL_0970.nii.gz
# Copying file 1982/2001: labelsTr/PARTIAL_0971.nii.gz
# Copying file 1983/2001: labelsTr/PARTIAL_0972.nii.gz
# Copying file 1984/2001: labelsTr/PARTIAL_0973.nii.gz
# Copying file 1985/2001: labelsTr/PARTIAL_0974.nii.gz
# Completed 1985/2001 files (99.2%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1985, batch_size=5)
#
#
# Processing batch 398: files 1986-1990 of 2001
# Copying file 1986/2001: labelsTr/PARTIAL_0976.nii.gz
# Copying file 1987/2001: labelsTr/PARTIAL_0977.nii.gz
# Copying file 1988/2001: labelsTr/PARTIAL_0980.nii.gz
# Copying file 1989/2001: labelsTr/PARTIAL_0982.nii.gz
# Copying file 1990/2001: labelsTr/PARTIAL_0987.nii.gz
# Completed 1990/2001 files (99.5%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1990, batch_size=5)
#
#
# Processing batch 399: files 1991-1995 of 2001
# Copying file 1991/2001: labelsTr/PARTIAL_0989.nii.gz
# Copying file 1992/2001: labelsTr/PARTIAL_0990.nii.gz
# Copying file 1993/2001: labelsTr/PARTIAL_0992.nii.gz
# Copying file 1994/2001: labelsTr/PARTIAL_0994.nii.gz
# Copying file 1995/2001: labelsTr/PARTIAL_0995.nii.gz
# Completed 1995/2001 files (99.7%)
# Pausing for 2 seconds before next batch...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=1995, batch_size=5)
#
#
# Processing batch 400: files 1996-2000 of 2001
# Copying file 1996/2001: labelsTr/PARTIAL_0996.nii.gz
# Copying file 1997/2001: labelsTr/PARTIAL_0997.nii.gz
# Copying file 1998/2001: labelsTr/PARTIAL_0998.nii.gz
# Copying file 1999/2001: labelsTr/PARTIAL_0999.nii.gz
# Copying file 2000/2001: labelsTr/isolate/PARTIAL_0528.nii.gz
# Completed 2000/2001 files (100.0%)
# Pausing for 2 seconds before next batch...
# Performing extensive garbage collection...
#
# If this process freezes, you can resume by running:
# robust_copy_directory("/content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial", "/content/nnUNet_raw/Dataset003_aocr2024_partial", start_idx=2000, batch_size=5)
#
#
# Processing batch 401: files 2001-2001 of 2001
# Copying file 2001/2001: labelsTr/isolate/PARTIAL_0438.nii.gz
# Completed 2001/2001 files (100.0%)
#
# Copy complete! Copied 2001 files from /content/drive/MyDrive/poster/NNUNET/nnUNet_raw/Dataset003_aocr2024_partial to /content/nnUNet_raw/Dataset003_aocr2024_partial
# Source files: 2001
# Destination files: 2001
# All files were copied successfully!

# %%
import os
import json

def generate_dataset_json(output_folder: str,
                          channel_names: dict,
                          labels: dict,
                          num_training_cases: int,
                          file_ending: str,
                          dataset_name: str = None,
                          overwrite_image_reader_writer: str = None,
                          ):
  """
  製作如下的json檔
  {
      "name": "nnunet-how-to",
      "channel_names": {
          "0": "CT"
      },
      "labels": {
          "background": 0,
          "AA": 1
      },
      "numTraining": 10,
      "file_ending": "nii.gz",
      "overwrite_image_reader_writer": "SimpleITKIO"
  }
  """
  # channel names need strings as keys
  keys = list(channel_names.keys())
  for k in keys:
      if not isinstance(k, str):
          channel_names[str(k)] = channel_names[k]
          del channel_names[k]

  # labels need ints as values
  for l in labels.keys():
      value = labels[l]
      if isinstance(value, (tuple, list)):
          value = tuple([int(i) for i in value])
          labels[l] = value
      else:
          labels[l] = int(labels[l])

  dataset_json = {
      'name': '',
      'channel_names': channel_names,
      'labels': labels,
      'numTraining': num_training_cases,
      'file_ending': file_ending,
      'overwrite_image_reader_writer': ''
  }

  if dataset_name is not None:
      dataset_json['name'] = dataset_name
  if overwrite_image_reader_writer is not None:
      dataset_json['overwrite_image_reader_writer'] = overwrite_image_reader_writer

  save_path = os.path.join(output_folder, 'dataset.json')
  with open(save_path, 'w') as f:
      json.dump(dataset_json, f, indent=4)

  print(f'dataset.json saved to {save_path}')

# %%
json_dir_path = '/content/nnUNet_raw/Dataset003_aocr2024_partial'
generate_dataset_json(json_dir_path,
                      {0: 'CT'},                              # channel_names
                      {"background": 0, "AA": 1, "HA": 2},    # labels
                      998,                                    # num_training_cases
                      '.nii.gz',                              # file_ending
                      overwrite_image_reader_writer='SimpleITKIO'
                      )
# Out:
# dataset.json saved to /content/nnUNet_raw/Dataset003_aocr2024_partial/dataset.json

# %% [markdown]
# ## plan and preprocess

# %% [markdown]
# nnUNetv2_plan_and_preprocess = nnUNetv2_extract_fingerprint + nnUNetv2_plan_experiment + nnUNetv2_preprocess

# %%
# !nnUNetv2_plan_and_preprocess -h

# %%
# !nnUNetv2_extract_fingerprint -d 3 --verify_dataset_integrity
# Out:
# Dataset003_aocr2024_partial
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
#
# ####################
# verify_dataset_integrity Done.
# If you didn't see any error messages then your dataset is most likely OK!
# ####################
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
# 100% 998/998 [01:49<00:00,  9.08it/s]

# %%
# !nnUNetv2_plan_experiment -d 3 -pl nnUNetPlannerResEncL
# Out:
# Dropping 3d_lowres config because the image size difference to 3d_fullres is too small. 3d_fullres: [ 50. 512. 512.], 3d_lowres: [50, 512, 512]
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 35, 'patch_size': (np.int64(512), np.int64(512)), 'median_image_size_in_voxels': array([512., 512.]), 'spacing': array([0.68359375, 0.68359375]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.ResidualEncoderUNet', 'arch_kwargs': {'n_stages': 8, 'features_per_stage': (32, 64, 128, 256, 512, 512, 512, 512), 'conv_op': 'torch.nn.modules.conv.Conv2d', 'kernel_sizes': ((3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3)), 'strides': ((1, 1), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2)), 'n_blocks_per_stage': (1, 3, 4, 6, 6, 6, 6, 6), 'n_conv_per_stage_decoder': (1, 1, 1, 1, 1, 1, 1), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm2d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': True}
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
# 3D fullres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': (np.int64(32), np.int64(384), np.int64(384)), 'median_image_size_in_voxels': array([ 50., 512., 512.]), 'spacing': array([5.        , 0.68359375, 0.68359375]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.ResidualEncoderUNet', 'arch_kwargs': {'n_stages': 7, 'features_per_stage': (32, 64, 128, 256, 320, 320, 320), 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': ((1, 3, 3), (1, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3)), 'strides': ((1, 1, 1), (1, 2, 2), (1, 2, 2), (2, 2, 2), (2, 2, 2), (2, 2, 2), (1, 2, 2)), 'n_blocks_per_stage': (1, 3, 4, 6, 6, 6, 6), 'n_conv_per_stage_decoder': (1, 1, 1, 1, 1, 1), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': False}
#
# Plans were saved to /content/nnUNet_preprocessed/Dataset003_aocr2024_partial/nnUNetResEncUNetLPlans.json

# %%
# !nnUNetv2_preprocess -h
# Out:
# usage: nnUNetv2_preprocess [-h] [-d D [D ...]] [-plans_name PLANS_NAME] [-c C [C ...]]
#                            [-np NP [NP ...]] [--verbose]
#
# options:
#   -h, --help            show this help message and exit
#   -d D [D ...]          [REQUIRED] List of dataset IDs. Example: 2 4 5. This will run fingerprint
#                         extraction, experiment planning and preprocessing for these datasets. Can
#                         of course also be just one dataset
#   -plans_name PLANS_NAME
#                         [OPTIONAL] You can use this to specify a custom plans file that you may
#                         have generated
#   -c C [C ...]          [OPTIONAL] Configurations for which the preprocessing should be run.
#                         Default: 2d 3d_fullres 3d_lowres. 3d_cascade_fullres does not need to be
#                         specified because it uses the data from 3d_fullres. Configurations that do
#                         not exist for some dataset will be skipped.
#   -np NP [NP ...]       [OPTIONAL] Use this to define how many processes are to be used. If this
#                         is just one number then this number of processes is used for all
#                         configurations specified with -c. If it's a list of numbers this list must
#                         have as many elements as there are configurations. We then iterate over
#                         zip(configs, num_processes) to determine then umber of processes used for
#                         each configuration. More processes is always faster (up to the number of
#                         threads your PC can support, so 8 for a 4 core CPU with hyperthreading. If
#                         you don't know what that is then dont touch it, or at least don't increase
#                         it!). DANGER: More often than not the number of processes that can be used
#                         is limited by the amount of RAM available. Image resampling takes up a lot
#                         of RAM. MONITOR RAM USAGE AND DECREASE -np IF YOUR RAM FILLS UP TOO MUCH!.
#                         Default: 8 processes for 2d, 4 for 3d_fullres, 8 for 3d_lowres and 4 for
#                         everything else
#   --verbose             Set this to print a lot of stuff. Useful for debugging. Will disable
#                         progress bar! Recommended for cluster environments

# %%
# !nnUNetv2_preprocess -d 3 \
                     -plans_name nnUNetResEncUNetLPlans \
                     -c 3d_fullres
# Out:
# Preprocessing dataset Dataset003_aocr2024_partial
# Configuration: 3d_fullres...
# 100% 998/998 [31:25<00:00,  1.89s/it]

# %% [markdown]
# ## train

# %%
# !nnUNetv2_train -h
# Out:
# usage: nnUNetv2_train [-h] [-tr TR] [-p P] [-pretrained_weights PRETRAINED_WEIGHTS]
#                       [-num_gpus NUM_GPUS] [--npz] [--c] [--val] [--val_best]
#                       [--disable_checkpointing] [-device DEVICE]
#                       dataset_name_or_id configuration fold
#
# positional arguments:
#   dataset_name_or_id    Dataset name or ID to train with
#   configuration         Configuration that should be trained
#   fold                  Fold of the 5-fold cross-validation. Should be an int between 0 and 4.
#
# options:
#   -h, --help            show this help message and exit
#   -tr TR                [OPTIONAL] Use this flag to specify a custom trainer. Default:
#                         nnUNetTrainer
#   -p P                  [OPTIONAL] Use this flag to specify a custom plans identifier. Default:
#                         nnUNetPlans
#   -pretrained_weights PRETRAINED_WEIGHTS
#                         [OPTIONAL] path to nnU-Net checkpoint file to be used as pretrained model.
#                         Will only be used when actually training. Beta. Use with caution.
#   -num_gpus NUM_GPUS    Specify the number of GPUs to use for training
#   --npz                 [OPTIONAL] Save softmax predictions from final validation as npz files (in
#                         addition to predicted segmentations). Needed for finding the best
#                         ensemble.
#   --c                   [OPTIONAL] Continue training from latest checkpoint
#   --val                 [OPTIONAL] Set this flag to only run the validation. Requires training to
#                         have finished.
#   --val_best            [OPTIONAL] If set, the validation will be performed with the
#                         checkpoint_best instead of checkpoint_final. NOT COMPATIBLE with
#                         --disable_checkpointing! WARNING: This will use the same 'validation'
#                         folder as the regular validation with no way of distinguishing the two!
#   --disable_checkpointing
#                         [OPTIONAL] Set this flag to disable checkpointing. Ideal for testing
#                         things out and you dont want to flood your hard drive with checkpoints.
#   -device DEVICE        Use this to set the device the training should run with. Available options
#                         are 'cuda' (GPU), 'cpu' (CPU) and 'mps' (Apple M1/M2). Do NOT use this to
#                         set which GPU ID! Use CUDA_VISIBLE_DEVICES=X nnUNetv2_train [...] instead!

# %%
# !nnUNetv2_train 3 3d_fullres 3 \
                -p nnUNetResEncUNetLPlans \
                --npz \
                --c
# Out:
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-18 02:43:44.648379: Using torch.compile...
# 2025-03-18 02:44:03.387612: do_dummy_2d_data_aug: True
# 2025-03-18 02:44:03.394195: Creating new 5-fold cross-validation split...
# 2025-03-18 02:44:03.403931: Desired fold for training: 3
# 2025-03-18 02:44:03.407138: This split has 799 training and 199 validation cases.
# using pin_memory on device 0
# using pin_memory on device 0
#
# This is the configuration used by this training:
# Configuration name: 3d_fullres
#  {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': [32, 384, 384], 'median_image_size_in_voxels': [50.0, 512.0, 512.0], 'spacing': [5.0, 0.68359375, 0.68359375], 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.ResidualEncoderUNet', 'arch_kwargs': {'n_stages': 7, 'features_per_stage': [32, 64, 128, 256, 320, 320, 320], 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': [[1, 3, 3], [1, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'strides': [[1, 1, 1], [1, 2, 2], [1, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [1, 2, 2]], 'n_blocks_per_stage': [1, 3, 4, 6, 6, 6, 6], 'n_conv_per_stage_decoder': [1, 1, 1, 1, 1, 1], 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ['conv_op', 'norm_op', 'dropout_op', 'nonlin']}, 'batch_dice': False}
#
# These are the global plan.json settings:
#  {'dataset_name': 'Dataset003_aocr2024_partial', 'plans_name': 'nnUNetResEncUNetLPlans', 'original_median_spacing_after_transp': [5.0, 0.68359375, 0.68359375], 'original_median_shape_after_transp': [50, 512, 512], 'image_reader_writer': 'SimpleITKIO', 'transpose_forward': [0, 1, 2], 'transpose_backward': [0, 1, 2], 'experiment_planner_used': 'nnUNetPlannerResEncL', 'label_manager': 'LabelManager', 'foreground_intensity_properties_per_channel': {'0': {'max': 1506.0, 'mean': 10.479762167507884, 'median': 29.0, 'min': -1024.0, 'percentile_00_5': -598.0, 'percentile_99_5': 129.0, 'std': 94.16644940334409}}}
#
# 2025-03-18 02:44:10.179222: Unable to plot network architecture: nnUNet_compile is enabled!
# 2025-03-18 02:44:10.852714:
# 2025-03-18 02:44:10.855967: Epoch 850
# 2025-03-18 02:44:10.859404: Current learning rate: 0.00181
# 2025-03-18 02:48:59.154335: train_loss -0.5492
# 2025-03-18 02:48:59.159431: val_loss -0.5297
# 2025-03-18 02:48:59.162671: Pseudo dice [np.float32(0.699), np.float32(0.0)]
# 2025-03-18 02:48:59.165890: Epoch time: 288.31 s
# 2025-03-18 02:48:59.168896: Yayy! New best EMA pseudo Dice: 0.3119
# 2025-03-18 02:49:15.768824:
# 2025-03-18 02:49:15.772308: Epoch 851
# 2025-03-18 02:49:15.775746: Current learning rate: 0.0018
# 2025-03-18 02:50:58.245260: train_loss -0.5188
# 2025-03-18 02:50:58.251084: val_loss -0.5105
# 2025-03-18 02:50:58.256252: Pseudo dice [np.float32(0.614), np.float32(0.0)]
# 2025-03-18 02:50:58.261986: Epoch time: 102.48 s
# 2025-03-18 02:50:59.656401:
# 2025-03-18 02:50:59.659870: Epoch 852
# 2025-03-18 02:50:59.663102: Current learning rate: 0.00179
# 2025-03-18 02:52:42.229314: train_loss -0.5466
# 2025-03-18 02:52:42.234009: val_loss -0.5615
# 2025-03-18 02:52:42.238280: Pseudo dice [np.float32(0.6866), np.float32(0.0)]
# 2025-03-18 07:32:33.077958: PARTIAL_0932, shape torch.Size([1, 50, 562, 562]), rank 0
# 2025-03-18 07:32:38.671402: predicting PARTIAL_0933
# 2025-03-18 07:32:38.755185: PARTIAL_0933, shape torch.Size([1, 50, 512, 512]), rank 0
# 2025-03-18 07:32:44.328926: predicting PARTIAL_0946
# 2025-03-18 07:32:44.399272: PARTIAL_0946, shape torch.Size([1, 50, 478, 478]), rank 0
# 2025-03-18 07:32:49.982320: predicting PARTIAL_0948
# 2025-03-18 07:32:50.080667: PARTIAL_0948, shape torch.Size([1, 50, 546, 546]), rank 0
# 2025-03-18 07:32:55.662479: predicting PARTIAL_0952
# 2025-03-18 07:32:55.758716: PARTIAL_0952, shape torch.Size([1, 50, 521, 521]), rank 0
# 2025-03-18 07:33:01.336981: predicting PARTIAL_0959
# 2025-03-18 07:33:01.444190: PARTIAL_0959, shape torch.Size([1, 50, 571, 571]), rank 0
# 2025-03-18 07:33:07.042121: predicting PARTIAL_0964
# 2025-03-18 07:33:07.150296: PARTIAL_0964, shape torch.Size([1, 50, 512, 512]), rank 0
# 2025-03-18 07:33:12.730276: predicting PARTIAL_0972
# 2025-03-18 07:33:12.785680: PARTIAL_0972, shape torch.Size([1, 50, 421, 421]), rank 0
# 2025-03-18 07:33:18.359170: predicting PARTIAL_0973
# 2025-03-18 07:33:18.440906: PARTIAL_0973, shape torch.Size([1, 50, 506, 506]), rank 0
# 2025-03-18 07:33:24.017240: predicting PARTIAL_0977
# 2025-03-18 07:33:24.087509: PARTIAL_0977, shape torch.Size([1, 50, 455, 455]), rank 0
# 2025-03-18 07:33:29.652589: predicting PARTIAL_0983
# 2025-03-18 07:33:29.750408: PARTIAL_0983, shape torch.Size([1, 50, 559, 559]), rank 0
# 2025-03-18 07:33:35.336545: predicting PARTIAL_0995
# 2025-03-18 07:33:35.423028: PARTIAL_0995, shape torch.Size([1, 50, 497, 497]), rank 0
# 2025-03-18 07:33:40.993304: predicting PARTIAL_1000
# 2025-03-18 07:33:41.068910: PARTIAL_1000, shape torch.Size([1, 50, 483, 483]), rank 0
# 2025-03-18 07:34:20.250599: Validation complete
# 2025-03-18 07:34:20.253676: Mean Validation Dice:  0.36164314646254125

# %% [markdown]
# ## find best configuration

# %%
# !nnUNetv2_find_best_configuration -h
# Out:
# usage: nnUNetv2_find_best_configuration [-h] [-p P [P ...]] [-c C [C ...]] [-tr TR [TR ...]]
#                                         [-np NP] [-f F [F ...]] [--disable_ensembling]
#                                         [--no_overwrite]
#                                         dataset_name_or_id
#
# positional arguments:
#   dataset_name_or_id    Dataset Name or id
#
# options:
#   -h, --help            show this help message and exit
#   -p P [P ...]          List of plan identifiers. Default: nnUNetPlans
#   -c C [C ...]          List of configurations. Default: ['2d', '3d_fullres', '3d_lowres',
#                         '3d_cascade_fullres']
#   -tr TR [TR ...]       List of trainers. Default: nnUNetTrainer
#   -np NP                Number of processes to use for ensembling, postprocessing etc
#   -f F [F ...]          Folds to use. Default: 0 1 2 3 4
#   --disable_ensembling  Set this flag to disable ensembling
#   --no_overwrite        If set we will not overwrite already ensembled files etc. May speed up
#                         concecutive runs of this command (why would you want to do that?) at the
#                         risk of not updating outdated results.

# %%
# !nnUNetv2_find_best_configuration 3 \
    -p nnUNetResEncUNetLPlans \
    -c 3d_fullres \
    -f 0 1 3
# Out:
# ***All results:***
# nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres: 0.30610593668230773
#
# *Best*: nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres: 0.30610593668230773
#
# ***Determining postprocessing for best model/ensemble***
# WARNING: Not all files in folder_ref were found in folder_predictions. Determining postprocessing should always be done on the entire dataset!
# Removing all but the largest foreground region did not improve results!
# Removing all but the largest component for 1 did not improve results! Dice before: 0.5057 after: 0.50516
# Removing all but the largest component for 2 did not improve results! Dice before: 0.10651 after: 0.10433
#
# ***Run inference like this:***
#
# nnUNetv2_predict -d Dataset003_aocr2024_partial -i INPUT_FOLDER -o OUTPUT_FOLDER -f  0 1 3 -tr nnUNetTrainer -c 3d_fullres -p nnUNetResEncUNetLPlans
#
# ***Once inference is completed, run postprocessing like this:***
#
# nnUNetv2_apply_postprocessing -i OUTPUT_FOLDER -o OUTPUT_FOLDER_PP -pp_pkl_file /content/drive/MyDrive/poster/NNUNET/nnUNet_results/Dataset003_aocr2024_partial/nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres/crossval_results_folds_0_1_3/postprocessing.pkl -np 8 -plans_json /content/drive/MyDrive/poster/NNUNET/nnUNet_results/Dataset003_aocr2024_partial/nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres/crossval_results_folds_0_1_3/plans.json

# %% [markdown]
# ## predict

# %%
# !cp -r '/content/drive/MyDrive/poster/NNUNET/predict/input_partial' '/content'

# %%
# !nnUNetv2_predict -d Dataset003_aocr2024_partial \
    -i "/content/input_partial" \
    -o "/content/drive/MyDrive/poster/NNUNET/predict/Dataset003_aocr2024_partial/nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres/fold_0_1_3/output" \
    -f  0 1 3 \
    -tr nnUNetTrainer \
    -c 3d_fullres \
    -p nnUNetResEncUNetLPlans
# Out:
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# There are 200 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 200 cases that I would like to predict
#
# Predicting PARTIAL_0001:
# perform_everything_on_device: True
# 100% 12/12 [00:10<00:00,  1.11it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0001
#
# Predicting PARTIAL_0002:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0002
#
# Predicting PARTIAL_0003:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0003
#
# Predicting PARTIAL_0004:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0004
#
# Predicting PARTIAL_0005:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0005
#
# Predicting PARTIAL_0006:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0006
#
# Predicting PARTIAL_0007:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0007
#
# Predicting PARTIAL_0008:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0008
#
# Predicting PARTIAL_0009:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0009
#
# Predicting PARTIAL_0010:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0010
#
# Predicting PARTIAL_0011:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0011
#
# Predicting PARTIAL_0012:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0012
#
# Predicting PARTIAL_0013:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0013
#
# Predicting PARTIAL_0014:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0014
#
# Predicting PARTIAL_0015:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0015
#
# Predicting PARTIAL_0016:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0016
#
# Predicting PARTIAL_0017:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0017
#
# Predicting PARTIAL_0018:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0018
#
# Predicting PARTIAL_0019:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0019
#
# Predicting PARTIAL_0020:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0020
#
# Predicting PARTIAL_0021:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0021
#
# Predicting PARTIAL_0022:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0022
#
# Predicting PARTIAL_0023:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0023
#
# Predicting PARTIAL_0024:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0024
#
# Predicting PARTIAL_0025:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0025
#
# Predicting PARTIAL_0026:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0026
#
# Predicting PARTIAL_0027:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0027
#
# Predicting PARTIAL_0028:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0028
#
# Predicting PARTIAL_0029:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0029
#
# Predicting PARTIAL_0030:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0030
#
# Predicting PARTIAL_0031:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0031
#
# Predicting PARTIAL_0032:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0032
#
# Predicting PARTIAL_0033:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0033
#
# Predicting PARTIAL_0034:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0034
#
# Predicting PARTIAL_0035:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0035
#
# Predicting PARTIAL_0036:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0036
#
# Predicting PARTIAL_0037:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0037
#
# Predicting PARTIAL_0038:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0038
#
# Predicting PARTIAL_0039:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0039
#
# Predicting PARTIAL_0040:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0040
#
# Predicting PARTIAL_0041:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0041
#
# Predicting PARTIAL_0042:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0042
#
# Predicting PARTIAL_0043:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0043
#
# Predicting PARTIAL_0044:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0044
#
# Predicting PARTIAL_0045:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0045
#
# Predicting PARTIAL_0046:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0046
#
# Predicting PARTIAL_0047:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0047
#
# Predicting PARTIAL_0048:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0048
#
# Predicting PARTIAL_0049:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0049
#
# Predicting PARTIAL_0050:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0050
#
# Predicting PARTIAL_0051:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0051
#
# Predicting PARTIAL_0052:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0052
#
# Predicting PARTIAL_0053:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0053
#
# Predicting PARTIAL_0054:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0054
#
# Predicting PARTIAL_0055:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0055
#
# Predicting PARTIAL_0056:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0056
#
# Predicting PARTIAL_0057:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0057
#
# Predicting PARTIAL_0058:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0058
#
# Predicting PARTIAL_0059:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0059
#
# Predicting PARTIAL_0060:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0060
#
# Predicting PARTIAL_0061:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0061
#
# Predicting PARTIAL_0062:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0062
#
# Predicting PARTIAL_0063:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0063
#
# Predicting PARTIAL_0064:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0064
#
# Predicting PARTIAL_0065:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0065
#
# Predicting PARTIAL_0066:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0066
#
# Predicting PARTIAL_0067:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0067
#
# Predicting PARTIAL_0068:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0068
#
# Predicting PARTIAL_0069:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0069
#
# Predicting PARTIAL_0070:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0070
#
# Predicting PARTIAL_0071:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0071
#
# Predicting PARTIAL_0072:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0072
#
# Predicting PARTIAL_0073:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0073
#
# Predicting PARTIAL_0074:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0074
#
# Predicting PARTIAL_0075:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0075
#
# Predicting PARTIAL_0076:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0076
#
# Predicting PARTIAL_0077:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0077
#
# Predicting PARTIAL_0078:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0078
#
# Predicting PARTIAL_0079:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0079
#
# Predicting PARTIAL_0080:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0080
#
# Predicting PARTIAL_0081:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0081
#
# Predicting PARTIAL_0082:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0082
#
# Predicting PARTIAL_0083:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0083
#
# Predicting PARTIAL_0084:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0084
#
# Predicting PARTIAL_0085:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0085
#
# Predicting PARTIAL_0086:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0086
#
# Predicting PARTIAL_0087:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0087
#
# Predicting PARTIAL_0088:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0088
#
# Predicting PARTIAL_0089:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0089
#
# Predicting PARTIAL_0090:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0090
#
# Predicting PARTIAL_0091:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0091
#
# Predicting PARTIAL_0092:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0092
#
# Predicting PARTIAL_0093:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0093
#
# Predicting PARTIAL_0094:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0094
#
# Predicting PARTIAL_0095:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0095
#
# Predicting PARTIAL_0096:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0096
#
# Predicting PARTIAL_0097:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0097
#
# Predicting PARTIAL_0098:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0098
#
# Predicting PARTIAL_0099:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0099
#
# Predicting PARTIAL_0100:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0100
#
# Predicting PARTIAL_0101:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0101
#
# Predicting PARTIAL_0102:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0102
#
# Predicting PARTIAL_0103:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0103
#
# Predicting PARTIAL_0104:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0104
#
# Predicting PARTIAL_0105:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0105
#
# Predicting PARTIAL_0106:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0106
#
# Predicting PARTIAL_0107:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0107
#
# Predicting PARTIAL_0108:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0108
#
# Predicting PARTIAL_0109:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0109
#
# Predicting PARTIAL_0110:
# perform_everything_on_device: True
# 100% 4/4 [00:02<00:00,  1.39it/s]
# 100% 4/4 [00:02<00:00,  1.39it/s]
# 100% 4/4 [00:02<00:00,  1.39it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0110
#
# Predicting PARTIAL_0111:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0111
#
# Predicting PARTIAL_0112:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0112
#
# Predicting PARTIAL_0113:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0113
#
# Predicting PARTIAL_0114:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0114
#
# Predicting PARTIAL_0115:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0115
#
# Predicting PARTIAL_0116:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0116
#
# Predicting PARTIAL_0117:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0117
#
# Predicting PARTIAL_0118:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0118
#
# Predicting PARTIAL_0119:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0119
#
# Predicting PARTIAL_0120:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0120
#
# Predicting PARTIAL_0121:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0121
#
# Predicting PARTIAL_0122:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0122
#
# Predicting PARTIAL_0123:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0123
#
# Predicting PARTIAL_0124:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0124
#
# Predicting PARTIAL_0125:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0125
#
# Predicting PARTIAL_0126:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0126
#
# Predicting PARTIAL_0127:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0127
#
# Predicting PARTIAL_0128:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0128
#
# Predicting PARTIAL_0129:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0129
#
# Predicting PARTIAL_0130:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0130
#
# Predicting PARTIAL_0131:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0131
#
# Predicting PARTIAL_0132:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0132
#
# Predicting PARTIAL_0133:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0133
#
# Predicting PARTIAL_0134:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0134
#
# Predicting PARTIAL_0135:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0135
#
# Predicting PARTIAL_0136:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0136
#
# Predicting PARTIAL_0137:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0137
#
# Predicting PARTIAL_0138:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0138
#
# Predicting PARTIAL_0139:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0139
#
# Predicting PARTIAL_0140:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0140
#
# Predicting PARTIAL_0141:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0141
#
# Predicting PARTIAL_0142:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0142
#
# Predicting PARTIAL_0143:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0143
#
# Predicting PARTIAL_0144:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0144
#
# Predicting PARTIAL_0145:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0145
#
# Predicting PARTIAL_0146:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0146
#
# Predicting PARTIAL_0147:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0147
#
# Predicting PARTIAL_0148:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0148
#
# Predicting PARTIAL_0149:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0149
#
# Predicting PARTIAL_0150:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0150
#
# Predicting PARTIAL_0151:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0151
#
# Predicting PARTIAL_0152:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0152
#
# Predicting PARTIAL_0153:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0153
#
# Predicting PARTIAL_0154:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0154
#
# Predicting PARTIAL_0155:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0155
#
# Predicting PARTIAL_0156:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0156
#
# Predicting PARTIAL_0157:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0157
#
# Predicting PARTIAL_0158:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0158
#
# Predicting PARTIAL_0159:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0159
#
# Predicting PARTIAL_0160:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0160
#
# Predicting PARTIAL_0161:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0161
#
# Predicting PARTIAL_0162:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0162
#
# Predicting PARTIAL_0163:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# 100% 27/27 [00:20<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0163
#
# Predicting PARTIAL_0164:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0164
#
# Predicting PARTIAL_0165:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0165
#
# Predicting PARTIAL_0166:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0166
#
# Predicting PARTIAL_0167:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0167
#
# Predicting PARTIAL_0168:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0168
#
# Predicting PARTIAL_0169:
# perform_everything_on_device: True
# 100% 4/4 [00:02<00:00,  1.39it/s]
# 100% 4/4 [00:02<00:00,  1.39it/s]
# 100% 4/4 [00:02<00:00,  1.39it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0169
#
# Predicting PARTIAL_0170:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0170
#
# Predicting PARTIAL_0171:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0171
#
# Predicting PARTIAL_0172:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0172
#
# Predicting PARTIAL_0173:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0173
#
# Predicting PARTIAL_0174:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0174
#
# Predicting PARTIAL_0175:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0175
#
# Predicting PARTIAL_0176:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0176
#
# Predicting PARTIAL_0177:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0177
#
# Predicting PARTIAL_0178:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0178
#
# Predicting PARTIAL_0179:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0179
#
# Predicting PARTIAL_0180:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0180
#
# Predicting PARTIAL_0181:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0181
#
# Predicting PARTIAL_0182:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0182
#
# Predicting PARTIAL_0183:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0183
#
# Predicting PARTIAL_0184:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0184
#
# Predicting PARTIAL_0185:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0185
#
# Predicting PARTIAL_0186:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0186
#
# Predicting PARTIAL_0187:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0187
#
# Predicting PARTIAL_0188:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0188
#
# Predicting PARTIAL_0189:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0189
#
# Predicting PARTIAL_0190:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0190
#
# Predicting PARTIAL_0191:
# perform_everything_on_device: True
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# 100% 27/27 [00:20<00:00,  1.34it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0191
#
# Predicting PARTIAL_0192:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0192
#
# Predicting PARTIAL_0193:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0193
#
# Predicting PARTIAL_0194:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0194
#
# Predicting PARTIAL_0195:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.35it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0195
#
# Predicting PARTIAL_0196:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.35it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0196
#
# Predicting PARTIAL_0197:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0197
#
# Predicting PARTIAL_0198:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0198
#
# Predicting PARTIAL_0199:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0199
#
# Predicting PARTIAL_0200:
# perform_everything_on_device: True
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# 100% 12/12 [00:08<00:00,  1.36it/s]
# sending off prediction to background worker for resampling and export
# done with PARTIAL_0200

# %% [markdown]
# ## postprocess

# %%
# !nnUNetv2_apply_postprocessing \
    -i '/content/drive/MyDrive/poster/NNUNET/predict/Dataset003_aocr2024_partial/nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres/fold_0_1_3/output' \
    -o '/content/drive/MyDrive/poster/NNUNET/predict/Dataset003_aocr2024_partial/nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres/fold_0_1_3/output_pp' \
    -pp_pkl_file /content/drive/MyDrive/poster/NNUNET/nnUNet_results/Dataset003_aocr2024_partial/nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres/crossval_results_folds_0_1_3/postprocessing.pkl \
    -np 8 \
    -plans_json /content/drive/MyDrive/poster/NNUNET/nnUNet_results/Dataset003_aocr2024_partial/nnUNetTrainer__nnUNetResEncUNetLPlans__3d_fullres/crossval_results_folds_0_1_3/plans.json
